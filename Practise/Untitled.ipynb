# %%
inport torch
# Out:
#   Input In [1]
#     inport torch
#            ^
# SyntaxError: invalid syntax

# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# /bin/bash: /home/developer/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: torch in /home/developer/anaconda3/lib/python3.9/site-packages (2.0.1)
# Requirement already satisfied: torchvision in /home/developer/anaconda3/lib/python3.9/site-packages (0.15.2)
# Requirement already satisfied: torchaudio in /home/developer/anaconda3/lib/python3.9/site-packages (2.0.2)
# Requirement already satisfied: filelock in /home/developer/anaconda3/lib/python3.9/site-packages (from torch) (3.6.0)
# Requirement already satisfied: typing-extensions in /home/developer/anaconda3/lib/python3.9/site-packages (from torch) (4.1.1)
# Requirement already satisfied: sympy in /home/developer/anaconda3/lib/python3.9/site-packages (from torch) (1.10.1)
# Requirement already satisfied: networkx in /home/developer/anaconda3/lib/python3.9/site-packages (from torch) (2.7.1)
# Requirement already satisfied: jinja2 in /home/developer/anaconda3/lib/python3.9/site-packages (from torch) (2.11.3)
# Requirement already satisfied: numpy in /home/developer/anaconda3/lib/python3.9/site-packages (from torchvision) (1.21.5)
# Requirement already satisfied: requests in /home/developer/anaconda3/lib/python3.9/site-packages (from torchvision) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/developer/anaconda3/lib/python3.9/site-packages (from torchvision) (9.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/developer/anaconda3/lib/python3.9/site-packages (from jinja2->torch) (2.0.1)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/developer/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/developer/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/developer/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /home/developer/anaconda3/lib/python3.9/site-packages (from requests->torchvision) (3.3)
# Requirement already satisfied: mpmath>=0.19 in /home/developer/anaconda3/lib/python3.9/site-packages (from sympy->torch) (1.2.1)

# %%
import torch

# %%
print(torch.cuda.is_available())
# Out:
# False

# %%
# !nvidia-smi
# Out:
# /bin/bash: /home/developer/anaconda3/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Tue Jan 21 10:18:57 2025
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.183.01             Driver Version: 535.183.01   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  NVIDIA GeForce RTX 3060        Off | 00000000:01:00.0  On |                  N/A |
# |  0%   39C    P8              10W / 170W |    376MiB / 12288MiB |      1%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |    0   N/A  N/A      1434      G   /usr/lib/xorg/Xorg                          118MiB |
# |    0   N/A  N/A      1576      G   /usr/bin/gnome-shell                         78MiB |
# |    0   N/A  N/A      4203      G   ...69,262144 --variations-seed-version       47MiB |
# |    0   N/A  N/A      7399      G   /usr/lib/firefox/firefox                    121MiB |
# +---------------------------------------------------------------------------------------+
